# %% [markdown]
# # Curating Film Dialogue

# %% [markdown]
# ## 1. Import the datasets
#
# Create a new Jupyter notebook called CuratingFilmDialogue.ipynb and read in the three datasets from the Github repository https://github.com/matthewfdaniels/scripts/.

# %%
import pandas as pd

# %% [markdown]
# ### metadata dataset

# %%
metadata = pd.read_csv('meta_data7.csv', encoding = 'latin-1')
metadata.head()
# Out:
#    script_id    imdb_id                       title  year  gross  \
# 0       1534  tt1022603        (500) Days of Summer  2009   37.0
# 1       1512  tt0147800  10 Things I Hate About You  1999   65.0
# 2       1514  tt0417385              12 and Holding  2005    NaN
# 3       1517  tt2024544            12 Years a Slave  2013   60.0
# 4       1520  tt1542344                   127 Hours  2010   20.0
#
#                                           lines_data
# 0  7435445256774774443342577775657744434444564456...
# 1  1777752320274533344457777722433777334443764677...
# 2  5461357777754212454544441367774433446547647753...
# 3  4567334777777777777777447777756477777444777777...
# 4                     453513352345765766777777773340

# %% [markdown]
# this is unique list of IMDB_IDs from the character_list file, with additional meta data, such as release year and domestic, inflation-adjusted gross.

# %% [markdown]
# ### character list dataset

# %%
character_list = pd.read_csv('character_list5.csv', encoding = 'latin-1')
character_list.head()
# Out:
#    script_id imdb_character_name  words gender   age
# 0        280               betty    311      f  35.0
# 1        280     carolyn johnson    873      f   NaN
# 2        280             eleanor    138      f   NaN
# 3        280     francesca johns   2251      f  46.0
# 4        280               madge    190      f  46.0

# %% [markdown]
# this is the data that powers all of the calculations on polygraph.cool/films. It uses the most accurate script that we can find for a given film. People are understandably finding errors, so we will be updating this file as much as possible.

# %% [markdown]
# ### character mapping dataset

# %%
character_mapping = pd.read_csv('character_mapping.csv', encoding = 'latin-1')
character_mapping.head()
# Out:
#    script_id    imdb_id character_from_script  \
# 0          1  tt0147800                bianca
# 1          1  tt0147800               cameron
# 2          1  tt0147800              chastity
# 3          1  tt0147800                  joey
# 4          1  tt0147800                   kat
#
#   closest_character_name_from_imdb_match closest_imdb_character_id
# 0                       bianca stratford                 nm0646351
# 1                          cameron james                 nm0330687
# 2                               chastity                 nm0005517
# 3                            joey donner                 nm0005080
# 4                          kat stratford                 nm0005466

# %% [markdown]
# ## 2. Check for missing data

# %% [markdown]
# ### metadata dataset

# %%
metadata.isna()
# Out:
#       script_id  imdb_id  title   year  gross  lines_data
# 0         False    False  False  False  False       False
# 1         False    False  False  False  False       False
# 2         False    False  False  False   True       False
# 3         False    False  False  False  False       False
# 4         False    False  False  False  False       False
# ...         ...      ...    ...    ...    ...         ...
# 1995      False    False  False  False  False       False
# 1996      False    False  False  False  False       False
# 1997      False    False  False  False  False       False
# 1998      False    False  False  False   True       False
# 1999      False    False  False  False  False       False
#
# [2000 rows x 6 columns]

# %%
import numpy as np
metadata_cols = ['script_id', 'imdb_id', 'title', 'year', 'gross', 'lines_data']
for col in metadata_cols:
    print(f'{col} : {np.unique(str(metadata[col].values))}\n')
# Out:
# script_id : ['[1534 1512 1514 ... 8158 3768 6491]']
#
# imdb_id : ["['tt1022603' 'tt0147800' 'tt0417385' ... 'tt0120906' 'tt0421090'\n 'tt0443706']"]
#
# title : ["['(500) Days of Summer' '10 Things I Hate About You' '12 and Holding' ...\n 'Zero Effect' 'Zerophilia' 'Zodiac']"]
#
# year : ['[2009 1999 2005 ... 1998 2005 2007]']
#
# gross : ['[37. 65. nan ...  3. nan 41.]']
#
# lines_data : ["['743544525677477444334257777565774443444456445674543367553452777734237544553444343334444444467441433777777777777776634344344434244343433435535624644435776576434333377775756764434344466346764533566544444777533356445543543343334444535476332345777777777777776'\n '177775232027453334445777772243377733444376467744677740424516733144464355045563543423354653735714457434333434243540000354213722445102431377774150047353236346777770432577633435475477734777720434517632245454363064653552333354735636524467333433433433530001363'\n '54613577777542124545444413677744334465476477533416774357535660534376444724437777421544734354157437777135461357777754212454544441367774433446547647753341677435753566053437644472443777742154473435415743777713'\n ...\n '47777744777776477777777777556777554236777777777777643442333312347777772177777735677777777777777333543332663774444453773'\n '764777444676334777777776377416345577777777763444432553412220477777777754446435433367774347777774444331000131643454764777444675335777777775477325345677777777754345423453412220577777777754346445334277773447777774354231000132634443'\n '244776776676356777777777777777776677777777777767654577777744445577777777777777775775777736777777674777677777337347764677776477237777752467336777777777']"]

# %%
metadata = pd.read_csv('meta_data7.csv', encoding = 'latin-1', na_values=['nan', 'False'])
new_metadata = metadata.dropna()
metadata.shape[0] - new_metadata.shape[0]
# Out:
# 338

# %% [markdown]
# missing data for metadata: nan, False
#
# I dropped 338 rows with missing data for the metadata dataset.

# %% [markdown]
# ### character list dataset

# %%
character_list.isna()
# Out:
#        script_id  imdb_character_name  words  gender    age
# 0          False                False  False   False  False
# 1          False                False  False   False   True
# 2          False                False  False   False   True
# 3          False                False  False   False  False
# 4          False                False  False   False  False
# ...          ...                  ...    ...     ...    ...
# 23043      False                False  False   False  False
# 23044      False                False  False   False  False
# 23045      False                False  False   False  False
# 23046      False                False  False   False  False
# 23047      False                False  False   False  False
#
# [23048 rows x 5 columns]

# %%
cl_cols = ['script_id', 'imdb_character_name', 'words', 'gender', 'age']
for col in cl_cols:
    print(f'{col} : {np.unique(str(character_list[col].values))}\n')
# Out:
# script_id : ['[ 280  280  280 ... 9254 9254 9254]']
#
# imdb_character_name : ['[\'betty\' \'carolyn johnson\' \'eleanor\' ... "monsieur d\'arqu" \'mrs. potts\'\n \'wardrobe\']']
#
# words : ['[311 873 138 ... 114 564 121]']
#
# gender : ["['f' 'f' 'f' ... 'm' 'f' 'f']"]
#
# age : ['[35. nan nan ... 58. 66. 54.]']

# %%
character_list = pd.read_csv('character_list5.csv', encoding = 'latin-1', na_values=['nan', 'False'])
new_character_list = character_list.dropna()
character_list.shape[0] - new_character_list.shape[0]
# Out:
# 4785

# %% [markdown]
# missing data for character list: nan, False
#
# I dropped 4785 rows with missing data for the character list dataset.

# %% [markdown]
# ### character mapping dataset

# %%
character_mapping.isna()
# Out:
#        script_id  imdb_id  character_from_script  \
# 0          False    False                  False
# 1          False    False                  False
# 2          False    False                  False
# 3          False    False                  False
# 4          False    False                  False
# ...          ...      ...                    ...
# 99385      False    False                  False
# 99386      False    False                  False
# 99387      False    False                  False
# 99388      False    False                  False
# 99389      False    False                  False
#
#        closest_character_name_from_imdb_match  closest_imdb_character_id
# 0                                       False                      False
# 1                                       False                      False
# 2                                       False                      False
# 3                                       False                      False
# 4                                       False                      False
# ...                                       ...                        ...
# 99385                                   False                      False
# 99386                                   False                      False
# 99387                                   False                      False
# 99388                                    True                      False
# 99389                                   False                      False
#
# [99390 rows x 5 columns]

# %%
cm_cols = ['script_id', 'imdb_id', 'character_from_script', 'closest_character_name_from_imdb_match', 'closest_imdb_character_id']
for col in cm_cols:
    print(f'{col} : {np.unique(str(character_mapping[col].values))}\n')
# Out:
# script_id : ['[   1    1    1 ... 9254 9254 9254]']
#
# imdb_id : ["['tt0147800' 'tt0147800' 'tt0147800' ... 'tt0101414' 'tt0101414'\n 'tt0101414']"]
#
# character_from_script : ["['bianca' 'cameron' 'chastity' ... 'mrs potts' 'townsfolk' 'wardrobe']"]
#
# closest_character_name_from_imdb_match : ["['bianca stratford' 'cameron james' 'chastity' ... 'mrs. potts' nan\n 'wardrobe']"]
#
# closest_imdb_character_id : ["['nm0646351' 'nm0330687' 'nm0005517' ... 'nm0001450' 'nm0621121'\n 'nm0941506']"]

# %%
character_mapping = pd.read_csv('character_mapping.csv', encoding = 'latin-1', na_values=['nan', 'nan\n', 'False'])
new_character_mapping = character_mapping.dropna()
character_mapping.shape[0] - new_character_mapping.shape[0]
# Out:
# 115

# %% [markdown]
# missing data for character mapping: nan, False, nan\n
#
# I dropped 115 rows with missing data for the character mapping dataset.

# %% [markdown]
# ## 3. Analysis questions

# %% [markdown]
# ### How could we tell if the amount of dialogue was increasing over time in movies? How might this influence the assessment about the breakdown of gender dialogue?

# %% [markdown]
# use the `lines_data` column in the `metadata` dataset to find the amount of dialogue in each movie and sort by by year and lines_data to see how it changed over time
#
# lines_data:
#
# - we assume that a minute of dialogue is roughly 14 lines
# - So each numeral in the string is the number of MALE lines for half a minute. So if split up the string into groups of two and add the two the numerals, we have total number of male lines of roughly a minute of time.
# - Each row is an array of [male lines out of 14 representing one minute, female lines out of 14 representing one minute]

# %% [markdown]
# gender dialogue:
# map `character_list` and `metadata` datasets using the `script_id` column
# `character_list` contains a `gender` column and `words` column, can see how the total number of words per film compares to the words said by characters of different genders within each movie

# %%
for idx,val in enumerate(new_metadata['lines_data']):
    my_str = str(val)
    #print(my_str)i
    my_sum = 0
    for i in my_str:
        if i.isdigit():
            my_sum += int(i)
    #print(my_sum)
    new_metadata.loc[idx, 'total_lines'] = my_sum
new_metadata
# Out:
# C:\Users\malli\AppData\Local\Temp\ipykernel_18100\2103799804.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_metadata.loc[idx, 'total_lines'] = my_sum
# C:\Users\malli\AppData\Local\Temp\ipykernel_18100\2103799804.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_metadata.loc[idx, 'total_lines'] = my_sum
#       script_id    imdb_id                       title    year  gross  \
# 0        1534.0  tt1022603        (500) Days of Summer  2009.0   37.0
# 1        1512.0  tt0147800  10 Things I Hate About You  1999.0   65.0
# 3        1517.0  tt2024544            12 Years a Slave  2013.0   60.0
# 4        1520.0  tt1542344                   127 Hours  2010.0   20.0
# 5        6537.0  tt0450385                        1408  2007.0   91.0
# ...         ...        ...                         ...     ...    ...
# 1642        NaN        NaN                         NaN     NaN    NaN
# 1643        NaN        NaN                         NaN     NaN    NaN
# 1647        NaN        NaN                         NaN     NaN    NaN
# 1652        NaN        NaN                         NaN     NaN    NaN
# 1659        NaN        NaN                         NaN     NaN    NaN
#
#                                              lines_data  total_lines
# 0     7435445256774774443342577775657744434444564456...       1215.0
# 1     1777752320274533344457777722433777334443764677...       1036.0
# 3     4567334777777777777777447777756477777444777777...        146.0
# 4                        453513352345765766777777773340        263.0
# 5          37677777777777777776777737566646444336777661        524.0
# ...                                                 ...          ...
# 1642                                                NaN        450.0
# 1643                                                NaN        431.0
# 1647                                                NaN        180.0
# 1652                                                NaN       1012.0
# 1659                                                NaN        440.0
#
# [1938 rows x 7 columns]

# %%
new_metadata.sort_values(by='year', ascending= True)
# Out:
#       script_id    imdb_id              title    year  gross  \
# 547      8521.0  tt0021884       Frankenstein  1931.0  298.0
# 1824     1483.0  tt0032138   The Wizard of Oz  1939.0  839.0
# 1042     3016.0  tt0031725          Ninotchka  1939.0   45.0
# 1794     6003.0  tt0041959      The Third Man  1949.0    8.0
# 1072     4745.0  tt0047296  On the Waterfront  1954.0  185.0
# ...         ...        ...                ...     ...    ...
# 1642        NaN        NaN                NaN     NaN    NaN
# 1643        NaN        NaN                NaN     NaN    NaN
# 1647        NaN        NaN                NaN     NaN    NaN
# 1652        NaN        NaN                NaN     NaN    NaN
# 1659        NaN        NaN                NaN     NaN    NaN
#
#                                              lines_data  total_lines
# 547   6343446777777777777777777777646447777777665775...        700.0
# 1824  0220005100004100267760000222343445342744445441...          NaN
# 1042  7777747757777777777545754333432344343343454343...        308.0
# 1794  7777777777777777777777777777747777443334435767...          NaN
# 1072  7777553677777777465467777677744434343343554543...        457.0
# ...                                                 ...          ...
# 1642                                                NaN        450.0
# 1643                                                NaN        431.0
# 1647                                                NaN        180.0
# 1652                                                NaN       1012.0
# 1659                                                NaN        440.0
#
# [1938 rows x 7 columns]

# %%
new_metadata.sort_values(by=['total_lines'], ascending= True)
# Out:
#       script_id    imdb_id                         title    year  gross  \
# 1283        NaN        NaN                           NaN     NaN    NaN
# 886      4553.0  tt0318155  Looney Tunes: Back in Action  2003.0   30.0
# 338      2029.0  tt0112697                      Clueless  1995.0  113.0
# 177         NaN        NaN                           NaN     NaN    NaN
# 1266        NaN        NaN                           NaN     NaN    NaN
# ...         ...        ...                           ...     ...    ...
# 1994     5517.0  tt3312830                         Youth  2015.0    2.0
# 1995     3765.0  tt0403702               Youth in Revolt  2009.0   17.0
# 1996     3766.0  tt1790885              Zero Dark Thirty  2012.0  104.0
# 1997     8158.0  tt0120906                   Zero Effect  1998.0    3.0
# 1999     6491.0  tt0443706                        Zodiac  2007.0   41.0
#
#                                              lines_data  total_lines
# 1283                                                NaN          2.0
# 886   7555765477777753477777763677772556745245766564...         11.0
# 338   5203350677316630521012342026300733222641636577...         21.0
# 177                                                 NaN         30.0
# 1266                                                NaN         31.0
# ...                                                 ...          ...
# 1994  7777777743477777777777777777777654336667757777...          NaN
# 1995  7766777656545344243247443314443342644634343374...          NaN
# 1996  5677677556654467677515744741445336433333000120...          NaN
# 1997  4777774477777647777777777755677755423677777777...          NaN
# 1999  2447767766763567777777777777777766777777777777...          NaN
#
# [1938 rows x 7 columns]

# %%
merged_df = pd.merge(new_character_list, new_metadata, on= 'script_id')
merged_df
# Out:
#        script_id imdb_character_name  words gender   age    imdb_id  \
# 0            280               betty    311      f  35.0  tt0112579
# 1            280     francesca johns   2251      f  46.0  tt0112579
# 2            280               madge    190      f  46.0  tt0112579
# 3            280     michael johnson    723      m  38.0  tt0112579
# 4            280      robert kincaid   1908      m  65.0  tt0112579
# ...          ...                 ...    ...    ...   ...        ...
# 15548       9254             lumiere   1063      m  56.0  tt0101414
# 15549       9254             maurice   1107      m  71.0  tt0101414
# 15550       9254     monsieur d'arqu    114      m  58.0  tt0101414
# 15551       9254          mrs. potts    564      f  66.0  tt0101414
# 15552       9254            wardrobe    121      f  54.0  tt0101414
#
#                                title    year  gross  \
# 0      The Bridges of Madison County  1995.0  142.0
# 1      The Bridges of Madison County  1995.0  142.0
# 2      The Bridges of Madison County  1995.0  142.0
# 3      The Bridges of Madison County  1995.0  142.0
# 4      The Bridges of Madison County  1995.0  142.0
# ...                              ...     ...    ...
# 15548           Beauty and the Beast  1991.0  452.0
# 15549           Beauty and the Beast  1991.0  452.0
# 15550           Beauty and the Beast  1991.0  452.0
# 15551           Beauty and the Beast  1991.0  452.0
# 15552           Beauty and the Beast  1991.0  452.0
#
#                                               lines_data  total_lines
# 0      4332023434343443203433434334433434343434434344...        706.0
# 1      4332023434343443203433434334433434343434434344...        706.0
# 2      4332023434343443203433434334433434343434434344...        706.0
# 3      4332023434343443203433434334433434343434434344...        706.0
# 4      4332023434343443203433434334433434343434434344...        706.0
# ...                                                  ...          ...
# 15548  3245753334377767774433634446467677732244465553...        452.0
# 15549  3245753334377767774433634446467677732244465553...        452.0
# 15550  3245753334377767774433634446467677732244465553...        452.0
# 15551  3245753334377767774433634446467677732244465553...        452.0
# 15552  3245753334377767774433634446467677732244465553...        452.0
#
# [15553 rows x 11 columns]

# %%
film_scripts = pd.read_csv('cleaned_pudding_data.csv')
film_scripts
films_year = film_scripts.groupby('year')['gross (inflation-adjusted)'].sum().reset_index()

# %%
merged_df.groupby('script_id')
merged_df
# Out:
#        script_id imdb_character_name  words gender   age    imdb_id  \
# 0            280               betty    311      f  35.0  tt0112579
# 1            280     francesca johns   2251      f  46.0  tt0112579
# 2            280               madge    190      f  46.0  tt0112579
# 3            280     michael johnson    723      m  38.0  tt0112579
# 4            280      robert kincaid   1908      m  65.0  tt0112579
# ...          ...                 ...    ...    ...   ...        ...
# 15548       9254             lumiere   1063      m  56.0  tt0101414
# 15549       9254             maurice   1107      m  71.0  tt0101414
# 15550       9254     monsieur d'arqu    114      m  58.0  tt0101414
# 15551       9254          mrs. potts    564      f  66.0  tt0101414
# 15552       9254            wardrobe    121      f  54.0  tt0101414
#
#                                title    year  gross  \
# 0      The Bridges of Madison County  1995.0  142.0
# 1      The Bridges of Madison County  1995.0  142.0
# 2      The Bridges of Madison County  1995.0  142.0
# 3      The Bridges of Madison County  1995.0  142.0
# 4      The Bridges of Madison County  1995.0  142.0
# ...                              ...     ...    ...
# 15548           Beauty and the Beast  1991.0  452.0
# 15549           Beauty and the Beast  1991.0  452.0
# 15550           Beauty and the Beast  1991.0  452.0
# 15551           Beauty and the Beast  1991.0  452.0
# 15552           Beauty and the Beast  1991.0  452.0
#
#                                               lines_data  total_lines
# 0      4332023434343443203433434334433434343434434344...        706.0
# 1      4332023434343443203433434334433434343434434344...        706.0
# 2      4332023434343443203433434334433434343434434344...        706.0
# 3      4332023434343443203433434334433434343434434344...        706.0
# 4      4332023434343443203433434334433434343434434344...        706.0
# ...                                                  ...          ...
# 15548  3245753334377767774433634446467677732244465553...        452.0
# 15549  3245753334377767774433634446467677732244465553...        452.0
# 15550  3245753334377767774433634446467677732244465553...        452.0
# 15551  3245753334377767774433634446467677732244465553...        452.0
# 15552  3245753334377767774433634446467677732244465553...        452.0
#
# [15553 rows x 11 columns]

# %% [markdown]
# ### How could we test if there was any relationship between the film’s gross value and the amount of dialogue in the film?
#
# - map the relationship between the `gross` and `lines_data` columns in the `metadata` dataset
# - calculate summary statistics for the different dataframes
# - use different types of visualizations such as scatterplots
